# %%
from matplotlib import pyplot as plt

# %%
week=[1,2,3,4,5,6,7]
shift1=[40,35,38,41,45,48,43]
shift2=[42,33,39,31,50,47,40]
shift3=[33,44,55,41,39,43,50]

# %%
plt.stackplot(week,shift1,shift2,shift3,labels=['shift1','shift2','shift3'])
plt.legend()
