# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Dataset2.csv')
data
# Out:
#     x1   x2   x3   x4    x5  x6  y
# 0    1  122  101  200  0.10  11  0
# 1    2  123  122  299  0.20  14  2
# 2    3  124  155  500  0.50  45  5
# 3    1  125  143  400  0.60  41  5
# 4    5  200   12  300  0.70  35  4
# 5    4  190  180  260  0.10  26  2
# 6    3  197  190  250  0.50  34  1
# 7    4  156   19  288  0.45  44  2
# 8    2  153  190  300  0.56  45  3
# 9    5  131  169  249  0.19  41  1
# 10   3  142  145  256  0.43  35  0
# 11   3  143  119  289  0.89  33  0
# 12   4  200  150  400  0.90  44  4
# 13   4  165  128  200  0.78  22  2
# 14   5  178  117  400  0.83  21  2
# 15   3  198  145  100  0.24  44  4
# 16   5  197  123  390  0.51  32  4
# 17   5  128  198  490  0.24  45  5
# 18   2  253  187  120  0.23  29  5

# %%
fid=plt.figure(figsize=(10,10))

# %%
plt.boxplot(data,patch_artist=True)
plt.xlabel('Data')
plt.show()
