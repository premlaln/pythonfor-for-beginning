# %%
from matplotlib import pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
#program for bar chart for year wise population in bangladesh

# %%
years=[2020,2021,2022,2023,2024]
population=[169356251,171186372,172954319,174701211,173562364]

# %%
plt.bar(years,population,color='blue')
plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Polation of Bangladesh")
plt.show()
