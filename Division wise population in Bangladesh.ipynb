# %%
populations_of_different_division=[9100102,33202326,44215107,17416645,12225498,20353119,17610956,11034863]
Divisions_name=['Barisal','Chittagong','Dhaka','Khulna','Mymensingh','Rajshahi','Rangpur','Sylhet']

# %%
import numpy as np
import matplotlib.pyplot as plt 
fig = plt.figure(figsize = (10, 5))
plt.bar(Divisions_name, populations_of_different_division, color ='maroon', 
        width = 0.4)

plt.xlabel("Population")
plt.ylabel("Divisions name")
plt.title("Population of different divisions in bangladesh")
plt.show()
